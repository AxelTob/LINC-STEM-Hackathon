# %%
# %pip install hackathon-linc==0.1.9
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import hackathon_linc as lh
import pandas as pd

lh.init('79c6af6c-1deb-46d7-b06e-a7c1901f6d2e')


data = lh.get_historical_data(days_back=5)
print(type(data))

df = pd.DataFrame(data)
df
# Out:
# C:\Users\AxelT\AppData\Local\Temp\ipykernel_25540\3536405982.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#     Welcome to the LINC Hackathon! Your token is now saved in the Console.
#     That means you don't need to carry that out when using the other functions
#     as long as you don't close your console.
#
#     This function is only to be used once to authenticate your token.
#
#     You can use the link below to view the dashboard:
#
#     hackathon.linclund.com
#
#     Happy coding!
#
#
# <class 'list'>
#     askMedian   askVolume  bidMedian   bidVolume              gmtTime  \
# ...

# %%
print(lh.buy("STOCK1", price=102, amount=1))
# Out:
# {'amount': 1, 'created_at': '2015-05-01T14:35:00', 'ended_at': None, 'id': '1b792d37-0562-410e-9191-0740caf484df', 'order_status': 'pending', 'order_type': 'buy', 'price': 102.0, 'security_id': '49b1df8a-2b2f-43a5-9b3e-036ef25439cf', 'team_id': 'a480aebd-26a4-4b8f-b3af-c0e135a0df7a'}

# %%
print(lh.get_completed_orders())
# Out:
# [{'amount': 1, 'created_at': '2015-04-27T12:15:00', 'ended_at': '2015-04-27T14:28:00', 'id': '32933ef1-ea91-4174-8635-d195794ea729', 'order_status': 'completed', 'order_type': 'buy', 'price': 75.94203333333333, 'security_id': '49b1df8a-2b2f-43a5-9b3e-036ef25439cf', 'symbol': 'STOCK1', 'team_id': 'a480aebd-26a4-4b8f-b3af-c0e135a0df7a'}, {'amount': 1, 'created_at': '2015-04-30T11:58:00', 'ended_at': '2015-04-30T12:59:00', 'id': 'bf376671-e288-4996-bc12-afd1cc9bc2fb', 'order_status': 'completed', 'order_type': 'buy', 'price': 73.7464, 'security_id': '49b1df8a-2b2f-43a5-9b3e-036ef25439cf', 'symbol': 'STOCK1', 'team_id': 'a480aebd-26a4-4b8f-b3af-c0e135a0df7a'}, {'amount': 1, 'created_at': '2015-05-01T14:35:00', 'ended_at': '2015-05-04T07:00:00', 'id': '1b792d37-0562-410e-9191-0740caf484df', 'order_status': 'completed', 'order_type': 'buy', 'price': 74.11898333333333, 'security_id': '49b1df8a-2b2f-43a5-9b3e-036ef25439cf', 'symbol': 'STOCK1', 'team_id': 'a480aebd-26a4-4b8f-b3af-c0e135a0df7a
# ...

# %%
from inspect import getmembers, isfunction

for x in getmembers(lh, isfunction):
    print(x)
# Out:
# ('buy', <function buy at 0x000001AEBA67B4C0>)
# ('cancel', <function cancel at 0x000001AEBA67B6A0>)
# ('get_all_orders', <function get_all_orders at 0x000001AEBA67B1A0>)
# ('get_all_tickers', <function get_all_tickers at 0x000001AEBA62A520>)
# ('get_balance', <function get_balance at 0x000001AEBA67B9C0>)
# ('get_completed_orders', <function get_completed_orders at 0x000001AEBA67B7E0>)
# ('get_current_price', <function get_current_price at 0x000001AEBA67B2E0>)
# ('get_historical_data', <function get_historical_data at 0x000001AEBA67B380>)
# ('get_pending_orders', <function get_pending_orders at 0x000001AEBA67B880>)
# ('get_portfolio', <function get_portfolio at 0x000001AEBA67BA60>)
# ('get_stoploss_orders', <function get_stoploss_orders at 0x000001AEBA67B920>)
# ('init', <function init at 0x000001AEBA2D27A0>)
# ('sell', <function sell at 0x000001AEBA67B560>)
# ('stoploss', <function stoploss at 0x000001AEBA67B600>)
